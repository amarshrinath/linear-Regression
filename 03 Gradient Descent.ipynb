# %% [markdown]
# # OPTIMIZATION, CALCULUS, DERIVATIVES,
# # BATCH GRADIENTS DESCENTS

# %%
# PREDICT>>CALCULATE ERROR>>>>LEARN>>PREDICT = ALGORITHM

# %% [markdown]
#  ## NOTEBOOK IMPORTS AND PACKAGES

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import cm # color map

# from mpl_toolkits.mplot3d.axes3d import Axes3D (earlier used now out of service)
from mpl_toolkits import mplot3d   #nnow use this library
from sympy import symbols, diff


from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error



# %matplotlib inline

# %% [markdown]
# # Example 1 a simple cost function/LOSS FUNCTION
# # $f(x) = x^2+x+1$

# %%
def f(x):
    return x**2 + x + 1

# %%
#MAKE DATA
x_l = np.linspace(start= -3, stop= 3, num= 100)

# %%
#PLOT
plt.figure(figsize= [6, 5])
plt.title("x vs f(x)")
plt.xlabel("x", fontsize= 16)
plt.ylabel("f(x)", fontsize= 16)

plt.xlim(-3, 2)
plt.ylim(0, 8)

plt.plot(x_l, f(x_l))
plt.show()

# %% [markdown]
# # slope and derivaties

# %%
def df(x):
    return 2*x + 1

# %%
#PLOT FUNCTION AND DERIVATIVE SIDE BY SIDE

plt.figure(figsize= (14, 6))

# 1 chart" : cost function (the graph of x vs f(x))

plt.subplot(1, 2, 1)
plt.title("cost function", fontsize= 17)        
plt.xlim(-3, 3)
plt.ylim(0, 8)        
plt.xlabel("x", fontsize= 16)
plt.ylabel("f(x)", fontsize= 16)
plt.plot(x_l, f(x_l), color= "blue", linewidth= 3)

#2 chart : derivativs function (the graph of xvs df(x))

plt.subplot(1, 2, 2)
plt.title("slope of the cosst function", fontsize= 17)
plt.xlabel("x", fontsize= 16)
plt.ylabel("df(x)", fontsize= 16)
plt.grid()                  
plt.xlim(-2, 3)
plt.ylim(-3, 6)
plt.plot(x_l, df(x_l), color= "skyblue", linewidth= 5)

plt.show()

# plt.grid() >> to add agrid in the graphs 
# plt.subplot(1, 2, 1) >> (row, column, num_graoh)

# %% [markdown]
# ## Python loops & Gradient Descent

# %%
#python for loop
for n in range(5):
    print("hello", n)
print("end of loop")
# Out:
# hello 0
# hello 1
# hello 2
# hello 3
# hello 4
# end of loop

# %%
#while loop
counter = 0
while counter < 7:
    print('counting...', counter)
    counter = counter + 1
print('end')
# Out:
# counting... 0
# counting... 1
# counting... 2
# counting... 3
# counting... 4
# counting... 5
# counting... 6
# end

# %%
# Gradient
new_x = 3                  #starting poimt
previous_x = 0             # previous value use in loop
step_multiplier = 0.1      #learning rates
precision = 0.0001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier*gradient
    
    step_size = abs(new_x - previous_x)
    x_list.append(new_x)
    slope_list.append(df(new_x))
   
    if step_size < precision:
        print('loop run this many time: ', n)
        break
print('stepsize = ', round(step_size, 4))
print('local min occure at:', new_x)
print('slope or df(x) occure at thind point is:', df(new_x))
print('f(x) value cost at this point is :', f(new_x))
# Out:
# loop run this many time:  40
# stepsize =  0.0001
# local min occure at: -0.49962781616118024
# slope or df(x) occure at thind point is: 0.0007443676776395236
# f(x) value cost at this point is : 0.7500001385208099

# %%
# Super Impose Gradient Descent Calculations on plot

plt.figure(figsize= (16, 6))

# 1 chart" : cost
plt.subplot(1, 3, 1)

plt.title("cost function", fontsize= 17)       
plt.xlim(-3, 3)
plt.ylim(0, 8)         
plt.xlabel("x", fontsize= 16)
plt.ylabel("f(x)", fontsize= 16)
plt.plot(x_l, f(x_l), color= "blue", linewidth= 3, alpha= 0.6)

values = np.array(x_list)
plt.scatter(x_list, f(values), color = 'red', s= 100, alpha= 0.6)

#2 chart : derivativs

plt.subplot(1, 3, 2)
plt.title("slope of the cosst function", fontsize= 17)
plt.xlabel("x", fontsize= 16)
plt.ylabel("df(x)", fontsize= 16)
plt.grid()                   
plt.xlim(-2, 3)
plt.ylim(-3, 6)
plt.plot(x_l, df(x_l), color= "skyblue", linewidth= 5, alpha= 0.6)
plt.scatter(x_list, slope_list, color= 'red', s= 100, alpha= 0.5)



#3 Gradient Descent (close up)

plt.subplot(1, 3, 3)

plt.title("Gradient Descent (close up)", fontsize= 17)
plt.xlabel("x", fontsize= 16)
plt.ylabel("df(x)", fontsize= 16)
plt.grid()                   
plt.xlim(-0.6,-0.2)
plt.ylim(-0.5, 0.75)
plt.plot(x_l, df(x_l), color= "skyblue", linewidth= 5, alpha= 0.6)
plt.scatter(x_list, slope_list, color= 'red', s= 100, alpha= 0.5)
plt.show()

# %% [markdown]
# ## Example 2 - multiple minima vs initial guess and advanced Functions
# ## $$g(x) = x^4 -4x^2 + 5$$

# %% [markdown]
# ## Defining function:

# %%
#make data
x_2 = np.linspace(-2, 2, 1000)

#cost function
def g(x):
    return x**4 - 4*x**2 + 5

# Derivative of function
def dg(x):
    return 4*x**3 - 8*x

# %% [markdown]
# ## slope and derivatives

# %%
#2 chart : derivativs

plt.figure(figsize= (6, 6))
plt.title("slope of the cosst function", fontsize= 17)
plt.xlabel("x", fontsize= 16)
plt.ylabel("dg(x)", fontsize= 16)
plt.grid()                   
plt.xlim(-2, 3)
plt.ylim(-5, 8)
plt.plot(x_2, dg(x_2), color= "skyblue", linewidth= 5, alpha= 0.6)


plt.show()

# %%
plt.figure(figsize= (12, 6))

# 1 chart" : cost
plt.subplot(1, 2, 1)

plt.title("cost function", fontsize= 17)        
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)       
plt.xlabel("x", fontsize= 16)
plt.ylabel("g(x)", fontsize= 16)
plt.plot(x_2, g(x_2), color= "blue", linewidth= 3, alpha= 0.6)



#2 chart : derivativs

plt.subplot(1, 2, 2)
plt.title("slope of the cosst function", fontsize= 17)
plt.xlabel("x", fontsize= 16)
plt.ylabel("dg(x)", fontsize= 16)
plt.grid()                   
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color= "skyblue", linewidth= 5, alpha= 0.6)


plt.show()

# %% [markdown]
# ## Gradient descent as python function

# %%
#definig function
def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter=300):
    """function provides minimum value"""

    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier*gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, initial_guess=0.5, multiplier=0.02, precision=0.001)
print('local min occure at: ', local_min)
print('number of steps: ', len(list_x))
# Out:
# local min occure at:  1.4122375085019094
# number of steps:  23

# %%
local_min, list_x, deriv_list = gradient_descent(dg, -0.5, 0.02, 0.001)
print('local min occure at: ', local_min)
print('number of steps: ', len(list_x))
# Out:
# local min occure at:  -1.4122375085019094
# number of steps:  23

# %%
# CALLING gradient Descent function

local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=0.1, multiplier= 0.02, precision= 0.001)
plt.figure(figsize= (13, 8))

# 1 chart" : cost
plt.subplot(1, 2, 1)
plt.title("cost function", fontsize= 17)        
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)        
plt.xlabel("x", fontsize= 16)
plt.ylabel("g(x)", fontsize= 16)
plt.plot(x_2, g(x_2), color= "blue", linewidth= 3, alpha= 0.8)
plt.scatter(list_x, g(np.array(list_x)), color= 'red', s= 200, alpha= 0.6)


#2 chart : derivativs

plt.subplot(1, 2, 2)
plt.title("slope of the cosst function", fontsize= 17)
plt.xlabel("x", fontsize= 16)
plt.ylabel("dg(x)", fontsize= 16)
plt.grid()                   
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color= "skyblue", linewidth= 5, alpha= 0.6)
plt.scatter(list_x, deriv_list, color= 'red', s= 200, alpha= 0.6)
plt.show()

# %% [markdown]
# ## Example3- Divergence, Overflow and python Tuples
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
#make data
x_3 = np.linspace(start= -2.5, stop= 2.5, num= 1000)

def h(x):
    return x**5 - 2*x**4 + 2

def dh(x):
    return 5*x**4 - 8*x**3

# %%
# CALLING gradient Descent function

local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=0.2, multiplier= 0.02, precision= 0.001)
plt.figure(figsize= (13, 8))

# 1 chart" : cost
plt.subplot(1, 2, 1)

plt.title("cost function", fontsize= 17)        
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)         
plt.xlabel("x", fontsize= 16)
plt.ylabel("g(x)", fontsize= 16)
plt.plot(x_2, g(x_2), color= "blue", linewidth= 3, alpha= 0.8)
plt.scatter(list_x, g(np.array(list_x)), color= 'red', s= 200, alpha= 0.6)


#2 chart : derivativs

plt.subplot(1, 2, 2)
plt.title("slope of the cosst function", fontsize= 17)
plt.xlabel("x", fontsize= 16)
plt.ylabel("dg(x)", fontsize= 16)
plt.grid()                  
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color= "skyblue", linewidth= 5, alpha= 0.6)
plt.scatter(list_x, deriv_list, color= 'red', s= 200, alpha= 0.6)


plt.show()

# %%
# CALLING gradient Descent function

local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=0.2,
                                                 multiplier= 0.02, precision= 0.001, max_iter= 200)
plt.figure(figsize= (13, 8))

# 1 chart" : cost
plt.subplot(1, 2, 1)

plt.title("cost function", fontsize= 17)          
plt.xlim(-1.2, 2.5)
plt.ylim(-1, 4)         
plt.xlabel("x", fontsize= 16)
plt.ylabel("h(x)", fontsize= 16)
plt.plot(x_3, h(x_3), color= "blue", linewidth= 3, alpha= 0.8)
plt.scatter(list_x, h(np.array(list_x)), color= 'red', s= 200, alpha= 0.6)


#2 chart : derivativs

plt.subplot(1, 2, 2)
plt.title("slope of the cosst function", fontsize= 17)
plt.xlabel("x", fontsize= 16)
plt.ylabel("dh(x)", fontsize= 16)
plt.grid()                   
plt.xlim(-1, 2)
plt.ylim(-4, 5)
plt.plot(x_3, dh(x_3), color= "skyblue", linewidth= 5, alpha= 0.6)
plt.scatter(list_x, deriv_list, color= 'red', s= 200, alpha= 0.6)


plt.show()

print('local min occure at :', local_min)
print('cost at this minimum is :', h(local_min))
print('number of steps takes are :', len(list_x))
# Out:
# local min occure at : 1.5989534547394717
# cost at this minimum is : -0.6214287992331258
# number of steps takes are : 117

# %%
import sys

# sys.version


sys.version
type(h(local_min))
sys.float_info.max
# Out:
# 1.7976931348623157e+308

# %% [markdown]
# ## python Tuples

# %%
# Creating tuples

# %%
name = ("amar", 1223, 23)

# %% [markdown]
# ## Learning Rate

# %%
# CALLING gradient Descent function

local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=-0.2,
                                                 multiplier= 0.02, precision= 0.001, max_iter= 71)
plt.figure(figsize= (13, 8))

# 1 chart" : cost
plt.subplot(1, 2, 1)

plt.title("cost function", fontsize= 17)         
plt.xlim(-1.2, 2.5)
plt.ylim(-1, 4)        
plt.xlabel("x", fontsize= 16)
plt.ylabel("h(x)", fontsize= 16)
plt.plot(x_3, h(x_3), color= "blue", linewidth= 3, alpha= 0.8)
plt.scatter(list_x, h(np.array(list_x)), color= 'red', s= 200, alpha= 0.6)


#2 chart : derivativs

plt.subplot(1, 2, 2)
plt.title("slope of the cosst function", fontsize= 17)
plt.xlabel("x", fontsize= 16)
plt.ylabel("dh(x)", fontsize= 16)
plt.grid()                   
plt.xlim(-1, 2)
plt.ylim(-4, 5)
plt.plot(x_3, dh(x_3), color= "skyblue", linewidth= 5, alpha= 0.6)
plt.scatter(list_x, deriv_list, color= 'red', s= 200, alpha= 0.6)


plt.show()

print('local min occure at :', local_min)
print('cost at this minimum is :', h(local_min))
print('number of steps takes are :', len(list_x))
# Out:
# local min occure at : -1.8398461123332792e+24
# cost at this minimum is : -2.1081790694225687e+121
# number of steps takes are : 72

# %% [markdown]
# ## LEARNING RATE

# %%
# CALLING gradient Descent function

local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier= 0.02, precision= 0.001,
                                                max_iter= 500)
plt.figure(figsize= (13, 8))

# 1 chart" : cost
plt.subplot(1, 2, 1)

plt.title("cost function", fontsize= 17)
          
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)        
plt.xlabel("x", fontsize= 16)
plt.ylabel("g(x)", fontsize= 16)
plt.plot(x_2, g(x_2), color= "blue", linewidth= 3, alpha= 0.8)
plt.scatter(list_x, g(np.array(list_x)), color= 'red', s= 200, alpha= 0.6)


#2 chart : derivativs

plt.subplot(1, 2, 2)
plt.title("slope of the cosst function", fontsize= 17)
plt.xlabel("x", fontsize= 16)
plt.ylabel("dg(x)", fontsize= 16)
plt.grid()                   
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color= "skyblue", linewidth= 5, alpha= 0.6)
plt.scatter(list_x, deriv_list, color= 'red', s= 200, alpha= 0.6)


plt.show()

print('no. os steps is :', len(list_x))
# Out:
# no. os steps is : 14

# %%
# CALLING gradient Descent 3 times
n= 100

low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier= 0.0005, precision= 0.0001,
                                                max_iter=n)

#plotting 2 more learning rates: mid_gamma(0.001), high_gamma= 0.002
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier= 0.001, precision= 0.0001,
                                                max_iter=n)

high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision= 0.0001,
                                                max_iter=n)

#experiment

exp_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision= 0.0001,
                                                max_iter=n)
#plotiing reduction in cost for ech iteration

plt.figure(figsize= (13, 8))
plt.title("cost function", fontsize= 17)
plt.xlim(0, n)
plt.ylim(0, 50)          
plt.xlabel("no. of iteration", fontsize= 16)
plt.ylabel("effect of the learning rate", fontsize= 16)

#value for our chart
#1. y-axis data: convert list into numpy array
low_value = np.array(low_gamma[1])

#y_axis data: create a list fron 0 to n+1
iteration_list = list(range(0, n+1))

#plotting low learning rate
plt.plot(iteration_list, g(low_value), color= "lightgreen", linewidth= 3)
plt.scatter(iteration_list, g(low_value), color= 'lightgreen', s= 100)


#plotting mid learning rate
plt.plot(iteration_list, g(np.array(mid_gamma[1])), color= "steelblue", linewidth= 3)
plt.scatter(iteration_list, g(np.array(mid_gamma[1])), color= 'steelblue', s= 100)


#plotting high learning rate
plt.plot(iteration_list, g(np.array(high_gamma[1])), color= "red", linewidth= 3)
plt.scatter(iteration_list, g(np.array(high_gamma[1])), color= 'red', s=100)


#plotting exp learning rate
plt.plot(iteration_list, g(np.array(exp_gamma[1])), color= "cyan", linewidth= 3)
plt.scatter(iteration_list, g(np.array(exp_gamma[1])), color= 'cyan', s=100)

plt.show()

# # np.array(high_gamma[1]).shape
# np.array(high_gamma[1]).shape
# # np.array(mid_gamma[1]).shape

# %% [markdown]
# # Example 4- 3d vizz and with 3d charts
# ## minimize $$f(x, y) = \frac{1}{r+1}$$
# ## minimize $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
def f(x, y):
    r = 3**(-x**2 - y**2)
    return 1/(r + 1)

# %%
#make our data
x_4 = np.linspace(start= -2, stop= 2, num= 100)
y_4 = np.linspace(start= -2, stop= 2, num= 100)


x_4, y_4 = np.meshgrid(x_4, y_4)

z = f(x_4, y_4)

# %%
#Generating 3d plot
fig = plt.figure(figsize= (16, 12))
ax = plt.axes(projection='3d')  #creating figure  (ax = plt.axes(projection='3d') earlier use function not use now)
ax.plot_surface(x_4, y_4, z, cmap= cm.coolwarm, alpha= 0.4)    # creating plot, cmap>> is color arguments
ax.set_xlabel('X', fontsize= 20)                                #https://matplotlib.org/2.0.2/users/colormaps.html>> for colormap selction
ax.set_ylabel('Y', fontsize= 20)
ax.set_zlabel('f(X,Y)', fontsize= 20)
plt.show()

# %%
# Import libraries
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt


# Creating dataset
x = np.outer(np.linspace(-3, 3, 32), np.ones(32))
y = x.copy().T # transpose
z = (np.sin(x **2) + np.cos(y **2) )

# Creating figure
fig = plt.figure(figsize =(14, 9))
ax = plt.axes(projection ='3d')
ax.plot_surface(x, y, z)

# show plot
plt.show()

# %% [markdown]
# ## partial derivative and symbolic function

# %%
#to see partial defferentiation different difening function in a, b

a, b = symbols('x, y')    #fedining other variable substitute as x = a, x = b usinf 'symbols' library

print('iN Our cost fun f(x, y) is:', f(a,b))   
print('partial derivative w r t x is :', diff(f(a, b), a))
print('value of f(x, y) at x=1.8, y= 1.0 is:', f(a, b).evalf(subs= {a:1.8, b:1.0}))

print('value of partial derivative wrt x:', diff(f(a, b), a).evalf(subs= {a:1.8, b:1.0})) 
#diff function in symobols use for differentiation
# Out:
# iN Our cost fun f(x, y) is: 1/(3**(-x**2 - y**2) + 1)
# partial derivative w r t x is : 2*3**(-x**2 - y**2)*x*log(3)/(3**(-x**2 - y**2) + 1)**2
# value of f(x, y) at x=1.8, y= 1.0 is: 0.990604794032582
# value of partial derivative wrt x: 0.0368089716197505

# %% [markdown]
# ## Batch gradient Descent with Sympy

# %%
#set up

multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs= {a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs= {a:params[0], b:params[1]})
    gradient = np.array([gradient_x, gradient_y])
    params = params - multiplier*gradient
    
#results:
print('value in gradient array:', gradient)
print('minimum value occure at x value of', params[0])
print('minimum value occure at y value of', params[1])
print('the cost is :', f(params[0], params[1]))
# Out:
# value in gradient array: [2.01013037525579e-11 1.11673909736433e-11]
# minimum value occure at x value of 3.45838599885832e-11
# minimum value occure at y value of 1.92132555492129e-11
# the cost is : 0.500000000000000

# %% [markdown]
# ## Partial derivatives
#
# ## $$ \frac{\partial f}{\partial x} = \frac{2x \ln(3) \cdot 3^{-x^2 - y^2}}{(3^{-x^2 - y^2} + 1)^2}$$
#
#
# ## $$ \frac{\partial f}{\partial y} = \frac{2y \ln(3) \cdot 3^{-x^2 - y^2}}{(3^{-x^2 - y^2} + 1)^2}$$

# %%
# Partial derivatives function example 4
from math import log


def fpx(x, y):
    r = 3**(-x**2 - y**2)
    return 2*x*log(3)*r/((r +1)**2)

def fpy(x, y):
    r = 3**(-x**2 - y**2)
    return 2*y*log(3)*r/((r +1)**2)  # if base of log is not defind then log is use as a natural log 'ln'

# %%
#set up
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradient = np.array([gradient_x, gradient_y])
    params = params - multiplier*gradient
    
#results:
print('value in gradient array:', gradient)
print('minimum value occure at x value of', params[0])
print('minimum value occure at y value of', params[1])
print('the cost is :', f(params[0], params[1]))
# Out:
# value in gradient array: [2.01013038e-11 1.11673910e-11]
# minimum value occure at x value of 3.458385998858304e-11
# minimum value occure at y value of 1.9213255549212797e-11
# the cost is : 0.5

# %% [markdown]
# ## Graphing 3D Gradient Descent and advance numpy array

# %%
#set up
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradient = np.array([gradient_x, gradient_y])
    params = params - multiplier*gradient
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis = 0)
    
#results:
print('value in gradient array:', gradient)
print('minimum value occure at x value of', params[0])
print('minimum value occure at y value of', params[1])
print('the cost is :', f(params[0], params[1]))
# Out:
# (1, 2)
# value in gradient array: [0.00046144 0.00025636]
# minimum value occure at x value of 0.0007938985101347202
# minimum value occure at y value of 0.0004410547278526219
# the cost is : 0.5000002265349848

# %%
#make our data
x_4 = np.linspace(start= -2, stop= 2, num= 100)
y_4 = np.linspace(start= -2, stop= 2, num= 100)


x_4, y_4 = np.meshgrid(x_4, y_4)

z = f(x_4, y_4)

# %%
#Generating 3d plot
fig = plt.figure(figsize= (16, 12))
ax = plt.axes(projection='3d')  

ax.set_xlabel('X', fontsize= 20)                              
ax.set_ylabel('Y', fontsize= 20)
ax.set_zlabel('f(X,Y)', fontsize= 20)

ax.plot_surface(x_4, y_4, z, cmap= cm.coolwarm, alpha= 0.4)  
ax.scatter(values_array[:,0], values_array[:,1],
           f(values_array[:,0], values_array[:,1]) , s= 50, color = 'red')
plt.show()

# %% [markdown]
# # Advance Numpy array

# %%
kirk = np.array([['captain', 'guitar']])
print(kirk.shape)

hs_band = np.array([['amar', 'chetan'], ['roshan', 'kunal']])
print('hs_band[0][0] : ', hs_band[0][0])

the_root = np.append(arr=kirk, values= hs_band, axis= 0) #arr= this is the array in which we have to append the value
# value= this is the value that we want to append in required array(in kirk)
#axix= 0 means we are adding value as a row if axix = 1 we adding values as a column
#values_array = np.append(values_array, params.reshape(1, 2), axis=0)
#values_array = np.concatenate((values_array, params.reshape(1, 2)), axis = 0)
    


the_root.shape 

print('printing nicknames.....', the_root[:, 0]) #[:] means all rows, [0] means 1st column

the_roots = np.append(arr= the_root, values= [['prashil', 'sagar']], axis= 0)
print('printing....', the_root[:, 1])
# Out:
# (1, 2)
# hs_band[0][0] :  amar
# printing nicknames..... ['captain' 'amar' 'roshan']
# printing.... ['guitar' 'chetan' 'kunal']

# %% [markdown]
# #  EXAMPLE 5: Working with data and real cost function
#
# ## mean square error: a cost function for regression problems
#
#
# ### $$RSS = \sum_{i-1}^{n} \big( y^{(i)} - h_\theta x^{i} \big)^2    $$
#
# ### $$MSE = \frac{1}{n} \sum_{i-1}^{n} \big( y^{(i)} - h_\theta x^{i} \big)^2    $$
#
# ### $$MSE = \frac{1}{n} \sum_{i-1}^{n} \big( y - \hat{y}\big)^2    $$

# %%
#MAKE SAMPLE DATA 
# x_5 = np.array([[1.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
# y_5 = np.array([[1.7, 2.4, 3.5, 3.0, 6.3, 9.4, 8.2 ]]).transpose()

#alternative

x_5 = np.array([0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]).reshape(7, 1)
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2 ]).reshape(7, 1)


print('Shape of x_array', x_5.shape)
print('Shape of x_array', y_5.shape)
# Out:
# Shape of x_array (7, 1)
# Shape of x_array (7, 1)

# %%
#Quick regression

regr = LinearRegression()
regr.fit(x_5, y_5)
print('theta 0:', regr.intercept_[0] )
print('theta 1:', regr.coef_[0][0] )
# Out:
# theta 0: 0.8475351486029536
# theta 1: 1.2227264637835915

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='red', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y = mx + c

y_hat = 0.8475351486029536 + 1.2227264637835915*x_5
print('estimated value: \n', y_hat)
print('actual y value : \n', y_5)
# Out:
# estimated value:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# actual y value :
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
def mse(y, y_hat):
   # mse_calc = 1/y.size * sum((y - y_hat)**2)
   # mse_calc = 1/7 * sum((y - y_hat)**2)
    mse_calc = np.average((y-y_hat)**2, axis=0)  


    return mse_calc

# %%
print('manually calculated', mse(y_5, y_hat))
print('mse using sklearn:', mean_squared_error(y_5, y_hat))
print('mse using sklearn:', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# manually calculated [0.94796558]
# mse using sklearn: 0.9479655759794577
# mse using sklearn: 0.9479655759794577

# %% [markdown]
# # 3D plot for mse cost function
# ## make the data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num = nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# # Calc MSE using neasted loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)
#         print(plot_t0[i][j])

# %%
print('shape of plot_t0:', plot_t0.shape)
print('shape of plot_t1:', plot_t1.shape)
print('shape of plot_cost:', plot_cost.shape)
# Out:
# shape of plot_t0: (200, 200)
# shape of plot_t1: (200, 200)
# shape of plot_cost: (200, 200)

# %%
# from mpl_toolkits import mplot3d
# import numpy as np
# import matplotlib.pyplot as plt

# # plotiing mse Generating 3d plot
# fig = plt.figure(figsize= (16, 12))
# ax = plt.subplot(projection='3d')  

# ax.set_xlabel('theta 0 ', fontsize= 20)                              
# ax.set_ylabel('theta 1', fontsize= 20)
# ax.set_zlabel('cost-mse', fontsize= 20)

# ax.plot_surface(plot_0, plot_1, plot_cost, alpha=0.3, cmap=cm.hot)  
# plt.show()

fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()
# Out:
# C:\Users\amar\AppData\Local\Temp/ipykernel_12464/4267610597.py:17: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
print('mean value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(indices=plot_cost.argmin(), shape= plot_cost.shape)

print('Min mse for theta 0 at plot_t0[111][91]', plot_t0[111][91])
print('min occure at (i, j):', ij_min)
print('Min mse for theta 1 at plot_t1[111][91]', plot_t1[111][91])
# Out:
# mean value of plot_cost 0.9483826526747164
# Min mse for theta 0 at plot_t0[111][91] 0.829145728643216
# min occure at (i, j): (111, 91)
# Min mse for theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# # Partia Derivatives of mse wrt $\theta_0$ and $\theta_1 $
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = -\frac{2}{n} \sum_{i=1}^{n} \big(y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) $$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = -\frac{2}{n} \sum_{i=1}^{n} \big(y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big(x^{(i)})$$

# %% [markdown]
# # MSE and Gradient Descent

# %%
# #x vakues y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
# def grade(x, y, thetas):
#     n = y.size
#     theta0_slope = (-2/n)*sum(y-thetas[0] - thetas[1]*x)
#     theta1_slope = (-2/n)*sum(y-thetas[0] - thetas[1]*x)*x
    
#     #return np.array([theta0_slope[0]], [theta1_slope[0]])
#     #return np.append(arr=theta0_slope, values=theta1_slope)
#     return np.concatenate((theta0_slope, theta1_slope), axis=0)


# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size
    
    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)
    
    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
# multiplier = 0.01
# thetas = np.array([2.9, 2.9])

# for i in range(1000):
#     thetas = thetas - multiplier*grade(x_5, y_5, thetas)
    
# #resuklt
# print('min occure at theta 0 :', thetas[0])
# print('min occure at theta 1 :', thetas[1])
# print('mse is :', mse(y_5, thetas[0] + thetas[1]*x_5))




multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)
    
    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))
    
# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot, alpha=0.4)
ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s = 100, color= 'black')
plt.show()
# Out:
# C:\Users\amar\AppData\Local\Temp/ipykernel_12464/1153912466.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
